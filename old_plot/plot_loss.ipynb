# %% [markdown]
# ## Code pour plot la loss

# %%
from utils import read_csv
import numpy as np
import matplotlib.pyplot as plt

# %%
# on ouvre le fichier de loss

folder_result = "results/2_model_2_case_1_zoom/epoch450"

csv_train = read_csv(folder_result + "/train_loss.csv")
csv_test = read_csv(folder_result + "/test_loss.csv")
train_total = list(csv_train['total'])
test_total = list(csv_test['total'])

plt.figure(figsize=(10, 6))
epochs = np.arange(len(train_total))
plt.plot(epochs, train_total, label='Loss d\'entraînement')
plt.plot(epochs, test_total, label='Loss de test')

# Configuration des axes logarithmiques
plt.yscale('log')

# Ajout de titres et légendes
plt.title('Loss d\'entraînement et de test')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.legend()
plt.grid(True, which="both", ls="--")

# Affichage du graphique
plt.show()

# %%
# on ouvre le fichier de loss

folder_result = "results/1_model_2_case_1/epoch1200"

csv_train = read_csv(folder_result + "/train_loss.csv")
csv_test = read_csv(folder_result + "/test_loss.csv")
train_total = list(csv_train['total'])
test_total = list(csv_test['total'])

plt.figure(figsize=(10, 6))
epochs = np.arange(len(train_total))
plt.plot(epochs, train_total, label='Loss d\'entraînement')
plt.plot(epochs, test_total, label='Loss de test')

# Configuration des axes logarithmiques
plt.yscale('log')

# Ajout de titres et légendes
plt.title('Loss d\'entraînement et de test')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.legend()
plt.grid(True, which="both", ls="--")

# Affichage du graphique
plt.show()

# %%
# on ouvre le fichier de loss

folder_result = "results/3_model_2_case_1_zoom_weights_modified/epoch350"

csv_train = read_csv(folder_result + "/train_loss.csv")
csv_test = read_csv(folder_result + "/test_loss.csv")
train_total = list(csv_train['total'])
test_total = list(csv_test['total'])

plt.figure(figsize=(10, 6))
epochs = np.arange(len(train_total))
plt.plot(epochs, train_total, label='Loss d\'entraînement')
plt.plot(epochs, test_total, label='Loss de test')

# Configuration des axes logarithmiques
plt.yscale('log')

# Ajout de titres et légendes
plt.title('Loss d\'entraînement et de test')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.legend()
plt.grid(True, which="both", ls="--")

# Affichage du graphique
plt.show()
